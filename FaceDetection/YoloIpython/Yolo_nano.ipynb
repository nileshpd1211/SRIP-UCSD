# %%
import os, time, random, argparse
import numpy as np
import tensorflow.keras.backend as K
from tensorflow.keras.utils import multi_gpu_model
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler, EarlyStopping, TerminateOnNaN, LambdaCallback
from tensorflow_model_optimization.sparsity import keras as sparsity

import sys
sys.path.insert(1, '../Yolo_support/')

from yolo3.model import get_yolo3_train_model
from yolo3.data import yolo3_data_generator_wrapper, Yolo3DataGenerator
from yolo2.model import get_yolo2_train_model
from yolo2.data import yolo2_data_generator_wrapper, Yolo2DataGenerator
from common.utils import get_classes, get_anchors, get_dataset, optimize_tf_gpu
from common.model_utils import get_optimizer
from common.callbacks import EvalCallBack, DatasetShuffleCallBack
import argparse
# Out:
# WARNING:tensorflow:From ../Yolo_support/common/utils.py:28: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From ../Yolo_support/common/utils.py:31: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From ../Yolo_support/common/utils.py:34: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %%
# Try to enable Auto Mixed Precision on TF 2.0
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'
os.environ['TF_AUTO_MIXED_PRECISION_GRAPH_REWRITE_IGNORE_PERFORMANCE'] = '1'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
optimize_tf_gpu(tf, K)

# %%
#All arguments required to form the network and train on CelebA dataset

parser = argparse.ArgumentParser()
# Model definition options
parser.add_argument('--model_type', type=str, required=False, default='yolo3_nano',
    help='YOLO model type: yolo3_mobilenet_lite/tiny_yolo3_mobilenet/yolo3_darknet/..., default=yolo2_mobilenet_lite')
parser.add_argument('--anchors_path', type=str, required=False, default='../Yolo_support/configs/yolo3_anchors.txt',
    help='path to anchor definitions, default=configs/yolo3_anchors.txt')
parser.add_argument('--model_image_size', type=str,required=False, default='416x416',
    help = "Initial model image input size as <num>x<num>, default 416x416")
parser.add_argument('--weights_path', type=str,required=False, default=None,
    help = "Pretrained model/weights file for fine tune")

# Data options
parser.add_argument('--annotation_file', type=str, required=False, default='../Yolo_support/celeba_train_small.txt',
    help='train annotation txt file, default=../Yolo_support/celeba_train_small.txt')
parser.add_argument('--val_annotation_file', type=str, required=False, default=None,
    help='val annotation txt file, default=None')
parser.add_argument('--val_split', type=float,required=False, default=0.1,
    help = "validation data persentage in dataset if no val dataset provide, default=0.1")
parser.add_argument('--classes_path', type=str, required=False, default='../Yolo_support/configs/voc_classes.txt',
    help='path to class definitions, default=configs/voc_classes.txt')

# Training options
parser.add_argument('--batch_size', type=int,required=False, default=16,
    help = "Batch size for train, default=16")
parser.add_argument('--optimizer', type=str,required=False, default='adam',
    help = "optimizer for training (adam/rmsprop/sgd), default=adam")
parser.add_argument('--learning_rate', type=float,required=False, default=1e-3,
    help = "Initial learning rate, default=0.001")
parser.add_argument('--decay_type', type=str,required=False, default=None,
    help = "Learning rate decay type (None/cosine/exponential/polynomial), default=None")
parser.add_argument('--transfer_epoch', type=int,required=False, default=20,
    help = "Transfer training (from Imagenet) stage epochs, default=20")
parser.add_argument('--freeze_level', type=int,required=False, default=None,
    help = "Freeze level of the model in transfer training stage. 0:NA/1:backbone/2:only open prediction layer")
parser.add_argument('--init_epoch', type=int,required=False, default=0,
    help = "Initial training epochs for fine tune training, default=0")
parser.add_argument('--total_epoch', type=int,required=False, default=250,
    help = "Total training epochs, default=250")
parser.add_argument('--multiscale', default=False, action="store_true",
    help='Whether to use multiscale training')
parser.add_argument('--rescale_interval', type=int, required=False, default=10,
    help = "Number of iteration(batches) interval to rescale input size, default=10")
parser.add_argument('--model_pruning', default=False, action="store_true",
    help='Use model pruning for optimization, only for TF 1.x')
parser.add_argument('--label_smoothing', type=float, required=False, default=0,
    help = "Label smoothing factor (between 0 and 1) for classification loss, default=0")
parser.add_argument('--data_shuffle', default=False, action="store_true",
    help='Whether to shuffle train/val data for cross-validation')
parser.add_argument('--gpu_num', type=int, required=False, default=1,
    help='Number of GPU to use, default=1')

# Evaluation options
parser.add_argument('--eval_online', default=False, action="store_true",
    help='Whether to do evaluation on validation dataset during training')
parser.add_argument('--eval_epoch_interval', type=int, required=False, default=10,
    help = "Number of iteration(epochs) interval to do evaluation, default=10")
parser.add_argument('--save_eval_checkpoint', default=False, action="store_true",
    help='Whether to save checkpoint with best evaluation result')

args = parser.parse_args(args=[])
print(args)

height, width = args.model_image_size.split('x')
args.model_image_size = (int(height), int(width))
# Out:
# Namespace(anchors_path='../Yolo_support/configs/yolo3_anchors.txt', annotation_file='../Yolo_support/celeba_train_small.txt', batch_size=16, classes_path='../Yolo_support/configs/voc_classes.txt', data_shuffle=False, decay_type=None, eval_epoch_interval=10, eval_online=False, freeze_level=None, gpu_num=1, init_epoch=0, label_smoothing=0, learning_rate=0.001, model_image_size='416x416', model_pruning=False, model_type='yolo3_nano', multiscale=False, optimizer='adam', rescale_interval=10, save_eval_checkpoint=False, total_epoch=250, transfer_epoch=20, val_annotation_file=None, val_split=0.1, weights_path=None)

# %%
def main(args):
    annotation_file = args.annotation_file
    log_dir = 'logs/002/'
    classes_path = args.classes_path
    class_names = get_classes(classes_path)
    num_classes = len(class_names)
    

    anchors = get_anchors(args.anchors_path)
    num_anchors = len(anchors)
    if args.weights_path:
        freeze_level = 0
    else:
        freeze_level = 1

    if args.freeze_level is not None:
        freeze_level = args.freeze_level


    # callbacks for training process
    logging = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=False, write_grads=False, write_images=False, update_freq='batch')
    checkpoint = ModelCheckpoint(log_dir + 'ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5',
        monitor='val_loss',
        verbose=1,
        save_weights_only=False,
        save_best_only=True,
        period=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1, cooldown=0, min_lr=1e-10)
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=50, verbose=1)
    terminate_on_nan = TerminateOnNaN()

    callbacks=[logging, checkpoint, reduce_lr, early_stopping, terminate_on_nan]

    # get train&val dataset
    dataset = get_dataset(annotation_file)
    if args.val_annotation_file:
        val_dataset = get_dataset(args.val_annotation_file)
        num_train = len(dataset)
        num_val = len(val_dataset)
        dataset.extend(val_dataset)
    else:
        val_split = args.val_split
        num_val = int(len(dataset)*val_split)
        num_train = len(dataset) - num_val

    # get different model type & train&val data generator
    if num_anchors == 9:
        # YOLOv3 use 9 anchors
        get_train_model = get_yolo3_train_model
        data_generator = yolo3_data_generator_wrapper
        tiny_version = False
    elif num_anchors == 6:
        # Tiny YOLOv3 use 6 anchors
        get_train_model = get_yolo3_train_model
        data_generator = yolo3_data_generator_wrapper
        tiny_version = True
    elif num_anchors == 5:
        # YOLOv2 use 5 anchors
        get_train_model = get_yolo2_train_model
        data_generator = yolo2_data_generator_wrapper
        tiny_version = False
    else:
        raise ValueError('Unsupported anchors number')

    # prepare online evaluation callback
    if args.eval_online:
        eval_callback = EvalCallBack(args.model_type, dataset[num_train:], anchors, class_names, args.model_image_size, args.model_pruning, log_dir, eval_epoch_interval=args.eval_epoch_interval, save_eval_checkpoint=args.save_eval_checkpoint)
        callbacks.append(eval_callback)

    # prepare train/val data shuffle callback
    if args.data_shuffle:
        shuffle_callback = DatasetShuffleCallBack(dataset)
        callbacks.append(shuffle_callback)

    # prepare model pruning config
    pruning_end_step = np.ceil(1.0 * num_train / args.batch_size).astype(np.int32) * args.total_epoch
    if args.model_pruning:
        pruning_callbacks = [sparsity.UpdatePruningStep(), sparsity.PruningSummaries(log_dir=log_dir, profile_batch=0)]
        callbacks = callbacks + pruning_callbacks

    # prepare optimizer
    optimizer = get_optimizer(args.optimizer, args.learning_rate, decay_type=None)

    # get train model
    model = get_train_model(args.model_type, anchors, num_classes, weights_path=args.weights_path, freeze_level=freeze_level, optimizer=optimizer, label_smoothing=args.label_smoothing, model_pruning=args.model_pruning, pruning_end_step=pruning_end_step)
    # support multi-gpu training
    template_model = None
    if args.gpu_num >= 2:
        # keep the template model for saving result
        template_model = model
        model = multi_gpu_model(model, gpus=args.gpu_num)
        # recompile multi gpu model
        model.compile(optimizer=optimizer, loss={'yolo_loss': lambda y_true, y_pred: y_pred})
    model.summary()

    # Transfer training some epochs with frozen layers first if needed, to get a stable loss.
    input_shape = args.model_image_size
    assert (input_shape[0]%32 == 0 and input_shape[1]%32 == 0), 'Multiples of 32 required'
    initial_epoch = args.init_epoch
    epochs = initial_epoch + args.transfer_epoch
    print("Transfer training stage")
    print('Train on {} samples, val on {} samples, with batch size {}, input_shape {}.'.format(num_train, num_val, args.batch_size, input_shape))
    model.fit_generator(data_generator(dataset[:num_train], args.batch_size, input_shape, anchors, num_classes),
            steps_per_epoch=max(1, num_train//args.batch_size),
            validation_data=data_generator(dataset[num_train:], args.batch_size, input_shape, anchors, num_classes),
            validation_steps=max(1, num_val//args.batch_size),
            epochs=epochs,
            initial_epoch=initial_epoch,
            workers=1,
            use_multiprocessing=False,
            max_queue_size=10,
            callbacks=callbacks)

    # Wait 2 seconds for next stage
    time.sleep(2)

    if args.decay_type:
        # rebuild optimizer to apply learning rate decay, only after
        # unfreeze all layers
        callbacks.remove(reduce_lr)
        steps_per_epoch = max(1, num_train//args.batch_size)
        decay_steps = steps_per_epoch * (args.total_epoch - args.init_epoch - args.transfer_epoch)
        optimizer = get_optimizer(args.optimizer, args.learning_rate, decay_type=args.decay_type, decay_steps=decay_steps)

    # Unfreeze the whole network for further tuning
    # NOTE: more GPU memory is required after unfreezing the body
    print("Unfreeze and continue training, to fine-tune.")
    for i in range(len(model.layers)):
        model.layers[i].trainable = True
    model.compile(optimizer=optimizer, loss={'yolo_loss': lambda y_true, y_pred: y_pred}) # recompile to apply the change


    if args.multiscale:
        rescale_interval = args.rescale_interval
    else:
        rescale_interval = -1  #Doesn't rescale

    print('Train on {} samples, val on {} samples, with batch size {}, input_shape {}.'.format(num_train, num_val, args.batch_size, input_shape))
    model.fit_generator(data_generator(dataset[:num_train], args.batch_size, input_shape, anchors, num_classes, rescale_interval),
        steps_per_epoch=max(1, num_train//args.batch_size),
        validation_data=data_generator(dataset[num_train:], args.batch_size, input_shape, anchors, num_classes),
        validation_steps=max(1, num_val//args.batch_size),
        epochs=args.total_epoch,
        initial_epoch=epochs,
        workers=1,
        use_multiprocessing=False,
        max_queue_size=10,
        callbacks=callbacks)

    # Finally store model
    if args.model_pruning:
        if template_model is not None:
            template_model = sparsity.strip_pruning(template_model)
        else:
            model = sparsity.strip_pruning(model)

    if template_model is not None:
        template_model.save(log_dir + 'trained_final.h5')
    else:
        model.save(log_dir + 'trained_final.h5')

# %%
main(args)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# WARNING:tensorflow:From /home/nppandey/.local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Create  YOLOv3 yolo3_nano model with 9 anchors and 1 classes.
# model layer number: 351
# Freeze the first 268 layers of total 351 layers.
# WARNING:tensorflow:From /home/nppandey/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py:4138: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image_input (InputLayer)        [(None, None, None,  0
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, None, None, 1 324         image_input[0][0]
# __________________________________________________________________________________________________
# Conv_1_BN (BatchNormalization)  (None, None, None, 1 48          Conv_1[0][0]
# __________________________________________________________________________________________________
# Conv_1_relu (ReLU)              (None, None, None, 1 0           Conv_1_BN[0][0]
# __________________________________________________________________________________________________
# Conv_2 (Conv2D)                 (None, None, None, 2 2592        Conv_1_relu[0][0]
# __________________________________________________________________________________________________
# Conv_2_BN (BatchNormalization)  (None, None, None, 2 96          Conv_2[0][0]
# __________________________________________________________________________________________________
# Conv_2_relu (ReLU)              (None, None, None, 2 0           Conv_2_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_1_preproject (Conv2D) (None, None, None, 7 168         Conv_2_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_1_preproject_BN (Batc (None, None, None, 7 28          pep_block_1_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_1_preproject_relu (Re (None, None, None, 7 0           pep_block_1_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_1_expand (Conv2D)     (None, None, None, 1 98          pep_block_1_preproject_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_1_expand_BN (BatchNor (None, None, None, 1 56          pep_block_1_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_1_expand_relu (ReLU)  (None, None, None, 1 0           pep_block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_1_depthwise (Depthwis (None, None, None, 1 126         pep_block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_1_depthwise_BN (Batch (None, None, None, 1 56          pep_block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_1_depthwise_relu (ReL (None, None, None, 1 0           pep_block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_1_project (Conv2D)    (None, None, None, 2 336         pep_block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_1_project_BN (BatchNo (None, None, None, 2 96          pep_block_1_project[0][0]
# __________________________________________________________________________________________________
# pep_block_1_add (Add)           (None, None, None, 2 0           Conv_2_relu[0][0]
#                                                                  pep_block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_1_expand (Conv2D)      (None, None, None, 4 1152        pep_block_1_add[0][0]
# __________________________________________________________________________________________________
# ep_block_1_expand_BN (BatchNorm (None, None, None, 4 192         ep_block_1_expand[0][0]
# __________________________________________________________________________________________________
# ep_block_1_expand_relu (ReLU)   (None, None, None, 4 0           ep_block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_1_pad (ZeroPadding2D)  (None, None, None, 4 0           ep_block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_1_depthwise (Depthwise (None, None, None, 4 432         ep_block_1_pad[0][0]
# __________________________________________________________________________________________________
# ep_block_1_depthwise_BN (BatchN (None, None, None, 4 192         ep_block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# ep_block_1_depthwise_relu (ReLU (None, None, None, 4 0           ep_block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_1_project (Conv2D)     (None, None, None, 7 3360        ep_block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_1_project_BN (BatchNor (None, None, None, 7 280         ep_block_1_project[0][0]
# __________________________________________________________________________________________________
# pep_block_2_preproject (Conv2D) (None, None, None, 2 1750        ep_block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_2_preproject_BN (Batc (None, None, None, 2 100         pep_block_2_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_2_preproject_relu (Re (None, None, None, 2 0           pep_block_2_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_2_expand (Conv2D)     (None, None, None, 5 1250        pep_block_2_preproject_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_2_expand_BN (BatchNor (None, None, None, 5 200         pep_block_2_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_2_expand_relu (ReLU)  (None, None, None, 5 0           pep_block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_2_depthwise (Depthwis (None, None, None, 5 450         pep_block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_2_depthwise_BN (Batch (None, None, None, 5 200         pep_block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_2_depthwise_relu (ReL (None, None, None, 5 0           pep_block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_2_project (Conv2D)    (None, None, None, 7 3500        pep_block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_2_project_BN (BatchNo (None, None, None, 7 280         pep_block_2_project[0][0]
# __________________________________________________________________________________________________
# pep_block_2_add (Add)           (None, None, None, 7 0           ep_block_1_project_BN[0][0]
#                                                                  pep_block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_3_preproject (Conv2D) (None, None, None, 2 1680        pep_block_2_add[0][0]
# __________________________________________________________________________________________________
# pep_block_3_preproject_BN (Batc (None, None, None, 2 96          pep_block_3_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_3_preproject_relu (Re (None, None, None, 2 0           pep_block_3_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_3_expand (Conv2D)     (None, None, None, 4 1152        pep_block_3_preproject_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_3_expand_BN (BatchNor (None, None, None, 4 192         pep_block_3_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_3_expand_relu (ReLU)  (None, None, None, 4 0           pep_block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_3_depthwise (Depthwis (None, None, None, 4 432         pep_block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_3_depthwise_BN (Batch (None, None, None, 4 192         pep_block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_3_depthwise_relu (ReL (None, None, None, 4 0           pep_block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_3_project (Conv2D)    (None, None, None, 7 3360        pep_block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_3_project_BN (BatchNo (None, None, None, 7 280         pep_block_3_project[0][0]
# __________________________________________________________________________________________________
# pep_block_3_add (Add)           (None, None, None, 7 0           pep_block_2_add[0][0]
#                                                                  pep_block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_2_expand (Conv2D)      (None, None, None, 1 9800        pep_block_3_add[0][0]
# __________________________________________________________________________________________________
# ep_block_2_expand_BN (BatchNorm (None, None, None, 1 560         ep_block_2_expand[0][0]
# __________________________________________________________________________________________________
# ep_block_2_expand_relu (ReLU)   (None, None, None, 1 0           ep_block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_2_pad (ZeroPadding2D)  (None, None, None, 1 0           ep_block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_2_depthwise (Depthwise (None, None, None, 1 1260        ep_block_2_pad[0][0]
# __________________________________________________________________________________________________
# ep_block_2_depthwise_BN (BatchN (None, None, None, 1 560         ep_block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# ep_block_2_depthwise_relu (ReLU (None, None, None, 1 0           ep_block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_2_project (Conv2D)     (None, None, None, 1 21000       ep_block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_2_project_BN (BatchNor (None, None, None, 1 600         ep_block_2_project[0][0]
# __________________________________________________________________________________________________
# pep_block_4_preproject (Conv2D) (None, None, None, 5 8400        ep_block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_4_preproject_BN (Batc (None, None, None, 5 224         pep_block_4_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_4_preproject_relu (Re (None, None, None, 5 0           pep_block_4_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_4_expand (Conv2D)     (None, None, None, 1 6272        pep_block_4_preproject_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_4_expand_BN (BatchNor (None, None, None, 1 448         pep_block_4_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_4_expand_relu (ReLU)  (None, None, None, 1 0           pep_block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_4_depthwise (Depthwis (None, None, None, 1 1008        pep_block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_4_depthwise_BN (Batch (None, None, None, 1 448         pep_block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_4_depthwise_relu (ReL (None, None, None, 1 0           pep_block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_4_project (Conv2D)    (None, None, None, 1 16800       pep_block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_4_project_BN (BatchNo (None, None, None, 1 600         pep_block_4_project[0][0]
# __________________________________________________________________________________________________
# pep_block_4_add (Add)           (None, None, None, 1 0           ep_block_2_project_BN[0][0]
#                                                                  pep_block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_pw_1 (Conv2D)              (None, None, None, 1 22500       pep_block_4_add[0][0]
# __________________________________________________________________________________________________
# Conv_pw_1_BN (BatchNormalizatio (None, None, None, 1 600         Conv_pw_1[0][0]
# __________________________________________________________________________________________________
# Conv_pw_1_relu (ReLU)           (None, None, None, 1 0           Conv_pw_1_BN[0][0]
# __________________________________________________________________________________________________
# fca_block_1_average_pooling (Gl (None, 150)          0           Conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# fca_block_1_fc1 (Dense)         (None, 18)           2718        fca_block_1_average_pooling[0][0]
# __________________________________________________________________________________________________
# fca_block_1_fc2 (Dense)         (None, 150)          2850        fca_block_1_fc1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 150)    0           fca_block_1_fc2[0][0]
# __________________________________________________________________________________________________
# fca_block_1_multiply (Multiply) (None, None, None, 1 0           reshape[0][0]
#                                                                  Conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_5_preproject (Conv2D) (None, None, None, 7 10950       fca_block_1_multiply[0][0]
# __________________________________________________________________________________________________
# pep_block_5_preproject_BN (Batc (None, None, None, 7 292         pep_block_5_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_5_preproject_relu (Re (None, None, None, 7 0           pep_block_5_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_5_expand (Conv2D)     (None, None, None, 1 10658       pep_block_5_preproject_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_5_expand_BN (BatchNor (None, None, None, 1 584         pep_block_5_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_5_expand_relu (ReLU)  (None, None, None, 1 0           pep_block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_5_depthwise (Depthwis (None, None, None, 1 1314        pep_block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_5_depthwise_BN (Batch (None, None, None, 1 584         pep_block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_5_depthwise_relu (ReL (None, None, None, 1 0           pep_block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_5_project (Conv2D)    (None, None, None, 1 21900       pep_block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_5_project_BN (BatchNo (None, None, None, 1 600         pep_block_5_project[0][0]
# __________________________________________________________________________________________________
# pep_block_5_add (Add)           (None, None, None, 1 0           fca_block_1_multiply[0][0]
#                                                                  pep_block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_6_preproject (Conv2D) (None, None, None, 7 10650       pep_block_5_add[0][0]
# __________________________________________________________________________________________________
# pep_block_6_preproject_BN (Batc (None, None, None, 7 284         pep_block_6_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_6_preproject_relu (Re (None, None, None, 7 0           pep_block_6_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_6_expand (Conv2D)     (None, None, None, 1 10082       pep_block_6_preproject_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_6_expand_BN (BatchNor (None, None, None, 1 568         pep_block_6_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_6_expand_relu (ReLU)  (None, None, None, 1 0           pep_block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_6_depthwise (Depthwis (None, None, None, 1 1278        pep_block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_6_depthwise_BN (Batch (None, None, None, 1 568         pep_block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_6_depthwise_relu (ReL (None, None, None, 1 0           pep_block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_6_project (Conv2D)    (None, None, None, 1 21300       pep_block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_6_project_BN (BatchNo (None, None, None, 1 600         pep_block_6_project[0][0]
# __________________________________________________________________________________________________
# pep_block_6_add (Add)           (None, None, None, 1 0           pep_block_5_add[0][0]
#                                                                  pep_block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_7_preproject (Conv2D) (None, None, None, 7 11250       pep_block_6_add[0][0]
# __________________________________________________________________________________________________
# pep_block_7_preproject_BN (Batc (None, None, None, 7 300         pep_block_7_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_7_preproject_relu (Re (None, None, None, 7 0           pep_block_7_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_7_expand (Conv2D)     (None, None, None, 1 11250       pep_block_7_preproject_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_7_expand_BN (BatchNor (None, None, None, 1 600         pep_block_7_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_7_expand_relu (ReLU)  (None, None, None, 1 0           pep_block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_7_depthwise (Depthwis (None, None, None, 1 1350        pep_block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_7_depthwise_BN (Batch (None, None, None, 1 600         pep_block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_7_depthwise_relu (ReL (None, None, None, 1 0           pep_block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_7_project (Conv2D)    (None, None, None, 1 22500       pep_block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_7_project_BN (BatchNo (None, None, None, 1 600         pep_block_7_project[0][0]
# __________________________________________________________________________________________________
# pep_block_7_add (Add)           (None, None, None, 1 0           pep_block_6_add[0][0]
#                                                                  pep_block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_3_expand (Conv2D)      (None, None, None, 3 45000       pep_block_7_add[0][0]
# __________________________________________________________________________________________________
# ep_block_3_expand_BN (BatchNorm (None, None, None, 3 1200        ep_block_3_expand[0][0]
# __________________________________________________________________________________________________
# ep_block_3_expand_relu (ReLU)   (None, None, None, 3 0           ep_block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_3_pad (ZeroPadding2D)  (None, None, None, 3 0           ep_block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_3_depthwise (Depthwise (None, None, None, 3 2700        ep_block_3_pad[0][0]
# __________________________________________________________________________________________________
# ep_block_3_depthwise_BN (BatchN (None, None, None, 3 1200        ep_block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# ep_block_3_depthwise_relu (ReLU (None, None, None, 3 0           ep_block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_3_project (Conv2D)     (None, None, None, 3 97500       ep_block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_3_project_BN (BatchNor (None, None, None, 3 1300        ep_block_3_project[0][0]
# __________________________________________________________________________________________________
# pep_block_8_preproject (Conv2D) (None, None, None, 1 42900       ep_block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_8_preproject_BN (Batc (None, None, None, 1 528         pep_block_8_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_8_preproject_relu (Re (None, None, None, 1 0           pep_block_8_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_8_expand (Conv2D)     (None, None, None, 2 34848       pep_block_8_preproject_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_8_expand_BN (BatchNor (None, None, None, 2 1056        pep_block_8_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_8_expand_relu (ReLU)  (None, None, None, 2 0           pep_block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_8_depthwise (Depthwis (None, None, None, 2 2376        pep_block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_8_depthwise_BN (Batch (None, None, None, 2 1056        pep_block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_8_depthwise_relu (ReL (None, None, None, 2 0           pep_block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_8_project (Conv2D)    (None, None, None, 3 85800       pep_block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_8_project_BN (BatchNo (None, None, None, 3 1300        pep_block_8_project[0][0]
# __________________________________________________________________________________________________
# pep_block_8_add (Add)           (None, None, None, 3 0           ep_block_3_project_BN[0][0]
#                                                                  pep_block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_9_preproject (Conv2D) (None, None, None, 1 40300       pep_block_8_add[0][0]
# __________________________________________________________________________________________________
# pep_block_9_preproject_BN (Batc (None, None, None, 1 496         pep_block_9_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_9_preproject_relu (Re (None, None, None, 1 0           pep_block_9_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_9_expand (Conv2D)     (None, None, None, 2 30752       pep_block_9_preproject_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_9_expand_BN (BatchNor (None, None, None, 2 992         pep_block_9_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_9_expand_relu (ReLU)  (None, None, None, 2 0           pep_block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_9_depthwise (Depthwis (None, None, None, 2 2232        pep_block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_9_depthwise_BN (Batch (None, None, None, 2 992         pep_block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_9_depthwise_relu (ReL (None, None, None, 2 0           pep_block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_9_project (Conv2D)    (None, None, None, 3 80600       pep_block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_9_project_BN (BatchNo (None, None, None, 3 1300        pep_block_9_project[0][0]
# __________________________________________________________________________________________________
# pep_block_9_add (Add)           (None, None, None, 3 0           pep_block_8_add[0][0]
#                                                                  pep_block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_10_preproject (Conv2D (None, None, None, 1 45825       pep_block_9_add[0][0]
# __________________________________________________________________________________________________
# pep_block_10_preproject_BN (Bat (None, None, None, 1 564         pep_block_10_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_10_preproject_relu (R (None, None, None, 1 0           pep_block_10_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_10_expand (Conv2D)    (None, None, None, 2 39762       pep_block_10_preproject_relu[0][0
# __________________________________________________________________________________________________
# pep_block_10_expand_BN (BatchNo (None, None, None, 2 1128        pep_block_10_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_10_expand_relu (ReLU) (None, None, None, 2 0           pep_block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_10_depthwise (Depthwi (None, None, None, 2 2538        pep_block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_10_depthwise_BN (Batc (None, None, None, 2 1128        pep_block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_10_depthwise_relu (Re (None, None, None, 2 0           pep_block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_10_project (Conv2D)   (None, None, None, 3 91650       pep_block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_10_project_BN (BatchN (None, None, None, 3 1300        pep_block_10_project[0][0]
# __________________________________________________________________________________________________
# pep_block_10_add (Add)          (None, None, None, 3 0           pep_block_9_add[0][0]
#                                                                  pep_block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_11_preproject (Conv2D (None, None, None, 1 45500       pep_block_10_add[0][0]
# __________________________________________________________________________________________________
# pep_block_11_preproject_BN (Bat (None, None, None, 1 560         pep_block_11_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_11_preproject_relu (R (None, None, None, 1 0           pep_block_11_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_11_expand (Conv2D)    (None, None, None, 2 39200       pep_block_11_preproject_relu[0][0
# __________________________________________________________________________________________________
# pep_block_11_expand_BN (BatchNo (None, None, None, 2 1120        pep_block_11_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_11_expand_relu (ReLU) (None, None, None, 2 0           pep_block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_11_depthwise (Depthwi (None, None, None, 2 2520        pep_block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_11_depthwise_BN (Batc (None, None, None, 2 1120        pep_block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_11_depthwise_relu (Re (None, None, None, 2 0           pep_block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_11_project (Conv2D)   (None, None, None, 3 91000       pep_block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_11_project_BN (BatchN (None, None, None, 3 1300        pep_block_11_project[0][0]
# __________________________________________________________________________________________________
# pep_block_11_add (Add)          (None, None, None, 3 0           pep_block_10_add[0][0]
#                                                                  pep_block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_12_preproject (Conv2D (None, None, None, 1 44525       pep_block_11_add[0][0]
# __________________________________________________________________________________________________
# pep_block_12_preproject_BN (Bat (None, None, None, 1 548         pep_block_12_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_12_preproject_relu (R (None, None, None, 1 0           pep_block_12_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_12_expand (Conv2D)    (None, None, None, 2 37538       pep_block_12_preproject_relu[0][0
# __________________________________________________________________________________________________
# pep_block_12_expand_BN (BatchNo (None, None, None, 2 1096        pep_block_12_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_12_expand_relu (ReLU) (None, None, None, 2 0           pep_block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_12_depthwise (Depthwi (None, None, None, 2 2466        pep_block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_12_depthwise_BN (Batc (None, None, None, 2 1096        pep_block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_12_depthwise_relu (Re (None, None, None, 2 0           pep_block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_12_project (Conv2D)   (None, None, None, 3 89050       pep_block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_12_project_BN (BatchN (None, None, None, 3 1300        pep_block_12_project[0][0]
# __________________________________________________________________________________________________
# pep_block_12_add (Add)          (None, None, None, 3 0           pep_block_11_add[0][0]
#                                                                  pep_block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_13_preproject (Conv2D (None, None, None, 1 43875       pep_block_12_add[0][0]
# __________________________________________________________________________________________________
# pep_block_13_preproject_BN (Bat (None, None, None, 1 540         pep_block_13_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_13_preproject_relu (R (None, None, None, 1 0           pep_block_13_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_13_expand (Conv2D)    (None, None, None, 2 36450       pep_block_13_preproject_relu[0][0
# __________________________________________________________________________________________________
# pep_block_13_expand_BN (BatchNo (None, None, None, 2 1080        pep_block_13_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_13_expand_relu (ReLU) (None, None, None, 2 0           pep_block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_13_depthwise (Depthwi (None, None, None, 2 2430        pep_block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_13_depthwise_BN (Batc (None, None, None, 2 1080        pep_block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_13_depthwise_relu (Re (None, None, None, 2 0           pep_block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_13_project (Conv2D)   (None, None, None, 3 87750       pep_block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_13_project_BN (BatchN (None, None, None, 3 1300        pep_block_13_project[0][0]
# __________________________________________________________________________________________________
# pep_block_13_add (Add)          (None, None, None, 3 0           pep_block_12_add[0][0]
#                                                                  pep_block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_14_preproject (Conv2D (None, None, None, 1 43225       pep_block_13_add[0][0]
# __________________________________________________________________________________________________
# pep_block_14_preproject_BN (Bat (None, None, None, 1 532         pep_block_14_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_14_preproject_relu (R (None, None, None, 1 0           pep_block_14_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_14_expand (Conv2D)    (None, None, None, 2 35378       pep_block_14_preproject_relu[0][0
# __________________________________________________________________________________________________
# pep_block_14_expand_BN (BatchNo (None, None, None, 2 1064        pep_block_14_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_14_expand_relu (ReLU) (None, None, None, 2 0           pep_block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_14_depthwise (Depthwi (None, None, None, 2 2394        pep_block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_14_depthwise_BN (Batc (None, None, None, 2 1064        pep_block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_14_depthwise_relu (Re (None, None, None, 2 0           pep_block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_14_project (Conv2D)   (None, None, None, 3 86450       pep_block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_14_project_BN (BatchN (None, None, None, 3 1300        pep_block_14_project[0][0]
# __________________________________________________________________________________________________
# pep_block_14_add (Add)          (None, None, None, 3 0           pep_block_13_add[0][0]
#                                                                  pep_block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_15_preproject (Conv2D (None, None, None, 1 45500       pep_block_14_add[0][0]
# __________________________________________________________________________________________________
# pep_block_15_preproject_BN (Bat (None, None, None, 1 560         pep_block_15_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_15_preproject_relu (R (None, None, None, 1 0           pep_block_15_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_15_expand (Conv2D)    (None, None, None, 2 39200       pep_block_15_preproject_relu[0][0
# __________________________________________________________________________________________________
# pep_block_15_expand_BN (BatchNo (None, None, None, 2 1120        pep_block_15_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_15_expand_relu (ReLU) (None, None, None, 2 0           pep_block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_15_depthwise (Depthwi (None, None, None, 2 2520        pep_block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_15_depthwise_BN (Batc (None, None, None, 2 1120        pep_block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_15_depthwise_relu (Re (None, None, None, 2 0           pep_block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_15_project (Conv2D)   (None, None, None, 3 91000       pep_block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_15_project_BN (BatchN (None, None, None, 3 1300        pep_block_15_project[0][0]
# __________________________________________________________________________________________________
# pep_block_15_add (Add)          (None, None, None, 3 0           pep_block_14_add[0][0]
#                                                                  pep_block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_4_expand (Conv2D)      (None, None, None, 6 211250      pep_block_15_add[0][0]
# __________________________________________________________________________________________________
# ep_block_4_expand_BN (BatchNorm (None, None, None, 6 2600        ep_block_4_expand[0][0]
# __________________________________________________________________________________________________
# ep_block_4_expand_relu (ReLU)   (None, None, None, 6 0           ep_block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_4_pad (ZeroPadding2D)  (None, None, None, 6 0           ep_block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_4_depthwise (Depthwise (None, None, None, 6 5850        ep_block_4_pad[0][0]
# __________________________________________________________________________________________________
# ep_block_4_depthwise_BN (BatchN (None, None, None, 6 2600        ep_block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# ...
# pep_block_20_depthwise_BN (Batc (None, None, None, 1 464         pep_block_20_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_20_depthwise_relu (Re (None, None, None, 1 0           pep_block_20_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_20_project (Conv2D)   (None, None, None, 1 14152       pep_block_20_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_20_project_BN (BatchN (None, None, None, 1 488         pep_block_20_project[0][0]
# __________________________________________________________________________________________________
# pep_block_21_preproject (Conv2D (None, None, None, 5 6344        pep_block_20_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_21_preproject_BN (Bat (None, None, None, 5 208         pep_block_21_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_21_preproject_relu (R (None, None, None, 5 0           pep_block_21_preproject_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_21_expand (Conv2D)    (None, None, None, 1 5408        pep_block_21_preproject_relu[0][0
# __________________________________________________________________________________________________
# pep_block_21_expand_BN (BatchNo (None, None, None, 1 416         pep_block_21_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_21_expand_relu (ReLU) (None, None, None, 1 0           pep_block_21_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_21_depthwise (Depthwi (None, None, None, 1 936         pep_block_21_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_21_depthwise_BN (Batc (None, None, None, 1 416         pep_block_21_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_21_depthwise_relu (Re (None, None, None, 1 0           pep_block_21_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_21_project (Conv2D)   (None, None, None, 8 9048        pep_block_21_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_21_project_BN (BatchN (None, None, None, 8 348         pep_block_21_project[0][0]
# __________________________________________________________________________________________________
# pep_block_22_preproject (Conv2D (None, None, None, 4 4089        pep_block_21_project_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_22_preproject_BN (Bat (None, None, None, 4 188         pep_block_22_preproject[0][0]
# __________________________________________________________________________________________________
# pep_block_22_preproject_relu (R (None, None, None, 4 0           pep_block_22_preproject_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_6_expand (Conv2D)      (None, None, None, 3 71442       Conv_pw_3[0][0]
# __________________________________________________________________________________________________
# ep_block_7_expand (Conv2D)      (None, None, None, 1 19208       conv2d_2[0][0]
# __________________________________________________________________________________________________
# pep_block_22_expand (Conv2D)    (None, None, None, 9 4418        pep_block_22_preproject_relu[0][0
# __________________________________________________________________________________________________
# ep_block_6_expand_BN (BatchNorm (None, None, None, 3 1512        ep_block_6_expand[0][0]
# __________________________________________________________________________________________________
# ep_block_7_expand_BN (BatchNorm (None, None, None, 1 784         ep_block_7_expand[0][0]
# __________________________________________________________________________________________________
# pep_block_22_expand_BN (BatchNo (None, None, None, 9 376         pep_block_22_expand[0][0]
# __________________________________________________________________________________________________
# ep_block_6_expand_relu (ReLU)   (None, None, None, 3 0           ep_block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_7_expand_relu (ReLU)   (None, None, None, 1 0           ep_block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_22_expand_relu (ReLU) (None, None, None, 9 0           pep_block_22_expand_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_6_depthwise (Depthwise (None, None, None, 3 3402        ep_block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_7_depthwise (Depthwise (None, None, None, 1 1764        ep_block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_22_depthwise (Depthwi (None, None, None, 9 846         pep_block_22_expand_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_6_depthwise_BN (BatchN (None, None, None, 3 1512        ep_block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# ep_block_7_depthwise_BN (BatchN (None, None, None, 1 784         ep_block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# pep_block_22_depthwise_BN (Batc (None, None, None, 9 376         pep_block_22_depthwise[0][0]
# __________________________________________________________________________________________________
# ep_block_6_depthwise_relu (ReLU (None, None, None, 3 0           ep_block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_7_depthwise_relu (ReLU (None, None, None, 1 0           ep_block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# pep_block_22_depthwise_relu (Re (None, None, None, 9 0           pep_block_22_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# ep_block_6_project (Conv2D)     (None, None, None, 4 174636      ep_block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_7_project (Conv2D)     (None, None, None, 1 35868       ep_block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# pep_block_22_project (Conv2D)   (None, None, None, 9 8742        pep_block_22_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# ep_block_6_project_BN (BatchNor (None, None, None, 4 1848        ep_block_6_project[0][0]
# __________________________________________________________________________________________________
# ep_block_7_project_BN (BatchNor (None, None, None, 1 732         ep_block_7_project[0][0]
# __________________________________________________________________________________________________
# pep_block_22_project_BN (BatchN (None, None, None, 9 372         pep_block_22_project[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 1 8334        ep_block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 3312        ep_block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 1692        pep_block_22_project_BN[0][0]
# __________________________________________________________________________________________________
# y_true_0 (InputLayer)           [(None, None, None,  0
# __________________________________________________________________________________________________
# y_true_1 (InputLayer)           [(None, None, None,  0
# __________________________________________________________________________________________________
# y_true_2 (InputLayer)           [(None, None, None,  0
# __________________________________________________________________________________________________
# yolo_loss (Lambda)              ((1,), (), (), ())   0           conv2d[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  y_true_0[0][0]
#                                                                  y_true_1[0][0]
#                                                                  y_true_2[0][0]
# __________________________________________________________________________________________________
# add_metric (AddMetric)          ()                   0           yolo_loss[0][1]
# __________________________________________________________________________________________________
# add_metric_1 (AddMetric)        ()                   0           yolo_loss[0][2]
# __________________________________________________________________________________________________
# add_metric_2 (AddMetric)        ()                   0           yolo_loss[0][3]
# ==================================================================================================
# Total params: 4,665,973
# Trainable params: 671,024
# Non-trainable params: 3,994,949
# __________________________________________________________________________________________________
# Transfer training stage
# Train on 3600 samples, val on 399 samples, with batch size 16, input_shape (416, 416).
# Epoch 1/20
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-b3f47c9a9b7f> in <module>
# ----> 1 main(args)
#
# <ipython-input-4-0c381af96701> in main(args)
#     112             use_multiprocessing=False,
#     113             max_queue_size=10,
# --> 114             callbacks=callbacks)
#     115
#     116     # Wait 2 seconds for next stage
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1294         shuffle=shuffle,
#    1295         initial_epoch=initial_epoch,
# -> 1296         steps_name='steps_per_epoch')
#    1297
#    1298   def evaluate_generator(self,
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     219     step = 0
#     220     while step < target_steps:
# --> 221       batch_data = _get_next_batch(generator)
#     222       if batch_data is None:
#     223         if is_dataset:
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_generator.py in _get_next_batch(generator)
#     361   """Retrieves the next batch of input data."""
#     362   try:
# --> 363     generator_output = next(generator)
#     364   except (StopIteration, errors.OutOfRangeError):
#     365     return None
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/utils/data_utils.py in get(self)
#     920             'Keras requires a thread-safe generator when '
#     921             '`use_multiprocessing=False, workers > 1`. ')
# --> 922       six.reraise(*sys.exc_info())
#
# /opt/conda/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/utils/data_utils.py in get(self)
#     896     try:
#     897       while self.is_running():
# --> 898         inputs = self.queue.get(block=True).get()
#     899         self.queue.task_done()
#     900         if inputs is not None:
#
# /opt/conda/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# /opt/conda/lib/python3.7/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     119         job, i, func, args, kwds = task
#     120         try:
# --> 121             result = (True, func(*args, **kwds))
#     122         except Exception as e:
#     123             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/utils/data_utils.py in next_sample(uid)
#     830       The next value of generator `uid`.
#     831   """
# --> 832   return six.next(_SHARED_SEQUENCES[uid])
#     833
#     834
#
# ~/SRIP/FaceDetection/Yolo_support/yolo3/data.py in yolo3_data_generator(annotation_lines, batch_size, input_shape, anchors, num_classes, rescale_interval)
#     224             if i==0:
#     225                 np.random.shuffle(annotation_lines)
# --> 226             image, box = get_ground_truth_data(annotation_lines[i], input_shape, augment=True)
#     227             image_data.append(image)
#     228             box_data.append(box)
#
# ~/SRIP/FaceDetection/Yolo_support/yolo3/data.py in get_ground_truth_data(annotation_line, input_shape, augment, max_boxes)
#      65
#      66     # reshape boxes based on augment
# ---> 67     boxes = reshape_boxes(boxes, src_shape=image_size, target_shape=model_input_size, padding_shape=padding_size, offset=padding_offset, horizontal_flip=horizontal_flip, vertical_flip=vertical_flip)
#      68     if len(boxes)>max_boxes:
#      69         boxes = boxes[:max_boxes]
#
# ~/SRIP/FaceDetection/Yolo_support/common/data_utils.py in reshape_boxes(boxes, src_shape, target_shape, padding_shape, offset, horizontal_flip, vertical_flip)
#     139         # shuffle and reshape boxes
#     140         np.random.shuffle(boxes)
# --> 141         boxes[:, [0,2]] = boxes[:, [0,2]]*padding_w/src_w + dx
#     142         boxes[:, [1,3]] = boxes[:, [1,3]]*padding_h/src_h + dy
#     143         # horizontal flip boxes if needed
#
# IndexError: index 2 is out of bounds for axis 1 with size 1
